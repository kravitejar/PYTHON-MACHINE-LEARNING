# %% [markdown]
# ## NATURAL LANGUAGE PROCESSING (NLP) USING NLTK LIBRARY

# %% [raw]
# (NLP): Its an act of allowing natural language input and putting it into a form that can be used by computers.
# Natural Language Processing is efficiently used in Artificial intelligence to simulate thought process successfully.

# %% [markdown]
# ### What is the need for NLP?

# %% [raw]
# we as human beings have the ability to understand languages it's our first achievements, also associating words to
# their meaning is natural. Machines dont have this ability.
# Hence we go for nlp, which is basically to help the machines understand the language and generate language between human being and machines.

# %% [markdown]
# ### InShort, natural language processing (NLP) is about developing applications and services that are able to understand human languages.

# %% [markdown]
# #### SOME PRACTICAL USES OF NLP
# speech recognition<br>
# speech translation<br>
# understanding complete sentences<br>
# understanding synonyms of matching words<br>
# writing complete grammatically correct sentences and paragraphs.

# %% [markdown]
# ### <b> LIBRARIES FOR NLP

# %% [markdown]
# <li> <b>Natural language toolkit (NLTK).
# <li> <b>Apache OpenNLP.
# <li> <b>Stanford NLP suite.
# <li> <b>Gate NLP library

# %% [markdown]
# ###### TERMS IN NLP

# %% [markdown]
# <ul class="list-group">
# <li>CORPUS
# <li>LEXICON
# <li>TOKEN
# <li>REPRESENTATION
# <li>BAG OF WORDS

# %% [markdown]
# #### CORPUS

# %% [markdown]
# CORPUS: Corpus is a homogeneous set of documents put together. In Other words, corpus is a list of items of each items is being a sentence or set of words
# <br>
# <b>
# ### <i> when we have multiple documents each document can be loaded into corpus as an item.
# <br>
# ### <i> when we have single document, each item for the corpus can be a paragraph/sentence/chapters
# </b>
#
# text1 ="Mary Had a little lamb"<br>
# text2 ="The quick brown fox jumps over the lazy dog"<br>
# text3 ="Humpty Dumpty Sat on a wall"<br>

# %% [markdown]
# ### LEXICON

# %% [markdown]
# Lexicon Refers to the meaning of the words.
# Homographs are words that have same spelling/pronunciation but mean different things.
# <b>
# bow<br>
# brace<br>
# buck<br>
# crane<br></b> can mean different things according to the context.

# %% [markdown]
# ## TOKEN

# %% [markdown]
# Token - Each "entity" that is a part of whatever was split up based on rules..<br>
# For examples, each word is a token when a sentence is "tokenized" into words.<br>
# Each sentence can also be a token, when a paragraph is  "tokenized" into sentences.<br>
# Each Paragraph is a token, when a document is "tokenized" into paragraphs.

# %% [markdown]
# ### BAG OF WORDS

# %% [markdown]
# Bag of words are set of tokens, to say the collection of tokens <br>
# (i) words in a sentence.<br>
# (ii) sentences in a paragraph.<br>
# (iii) paragraphs in a document.<br>

# %% [markdown]
# ### Lets Install NLTK

# %% [markdown]
# pip install nltk

# %% [markdown]
# <img src="data:image/png;base64,..." ></img>

# %% [markdown]
# ##### Lets Import NLTK ' we use the import nltk like other libraries to use nltk library for our code'

# %%
import nltk
nltk.download()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-3b02390c7677> in <module>
# ----> 1 import nltk
#       2 nltk.download()
#
# ModuleNotFoundError: No module named 'nltk'

# %%
text1 ="Mary Had a little lamb"
text2 ="The quick brown fox jumps over the lazy dog"
text3 ="Humpty Dumpty Sat on a wall"
corpus = [text1, text2, text3]

# %% [markdown]
# #### Import Nltk and download packages

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

EXAMPLE_TEXT = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."

print(sent_tokenize(EXAMPLE_TEXT))
print("####################################")
print(word_tokenize(EXAMPLE_TEXT))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-a962a747c175> in <module>
# ----> 1 from nltk.tokenize import sent_tokenize, word_tokenize
#       2
#       3 EXAMPLE_TEXT = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."
#       4
#       5 print(sent_tokenize(EXAMPLE_TEXT))
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# #### Frequency Distribution on NLTK

# %%
from bs4 import BeautifulSoup
import urllib.request
response = urllib.request.urlopen('http://php.net/')
html = response.read()
soup = BeautifulSoup(html,"html")
text = soup.get_text(strip=True)
#print (text)
 
tokens = [t for t in text.split()]
print (tokens)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-cd5fcc3941d3> in <module>
# ----> 1 from bs4 import BeautifulSoup
#       2 import urllib.request
#       3 response = urllib.request.urlopen('http://php.net/')
#       4 html = response.read()
#       5 soup = BeautifulSoup(html,"html")
#
# ModuleNotFoundError: No module named 'bs4'

# %%
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
     
freq.plot(20, cumulative=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-e14b8443f6bb> in <module>
# ----> 1 freq = nltk.FreqDist(tokens)
#       2 for key,val in freq.items():
#       3     print(str(key) + ':' + str(val))
#       4
#       5 freq.plot(20, cumulative=False)
#
# NameError: name 'nltk' is not defined

# %% [markdown]
# #### Removing Stop Words

# %%
from nltk.corpus import stopwords
stopwords.words('english')

clean_tokens = tokens[:]
sr = stopwords.words('english')

for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)
    
freq.plot(20, cumulative=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-418d9cfd28d0> in <module>
# ----> 1 from nltk.corpus import stopwords
#       2 stopwords.words('english')
#       3
#       4 clean_tokens = tokens[:]
#       5 sr = stopwords.words('english')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from bs4 import BeautifulSoup
import urllib.request
response = urllib.request.urlopen('http://php.net/')
html = response.read()
import requests
response = requests.get('http://php.net/')
print(response.text)
soup = BeautifulSoup(html,"html5lib")
text = soup.get_text(strip=True)
#print (text)
 
tokens = [t for t in text.split()]
#print (tokens)
clean_tokens = tokens[:]

for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-cc5a20515540> in <module>
# ----> 1 from bs4 import BeautifulSoup
#       2 import urllib.request
#       3 response = urllib.request.urlopen('http://php.net/')
#       4 html = response.read()
#       5 import requests
#
# ModuleNotFoundError: No module named 'bs4'

# %% [markdown]
# #### tokeninizing words using nltk

# %% [markdown]
# #### Sent Tokenize

# %%
from nltk.tokenize import sent_tokenize
mytext = "Hello Adam, how are you? I hope everything is going well. Today is a good day, see you dude."
print(sent_tokenize(mytext))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-ef0e0926fefc> in <module>
# ----> 1 from nltk.tokenize import sent_tokenize
#       2 mytext = "Hello Adam, how are you? I hope everything is going well. Today is a good day, see you dude."
#       3 print(sent_tokenize(mytext))
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# #### Word Tokenize

# %%
from nltk.tokenize import word_tokenize
print(word_tokenize(mytext))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-f9c0af8777f0> in <module>
# ----> 1 from nltk.tokenize import word_tokenize
#       2 print(word_tokenize(mytext))
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# #### Port steemmer

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()
example_words = ["python","pythoner","pythoning","pythoned","pythonly"]
for w in example_words:
    print(ps.stem(w))
print("###############################")
new_text = "It is important to by very pythonly while you are pythoning with python. All pythoners have pythoned poorly at least once."
words = word_tokenize(new_text)
for w in words:
    print(ps.stem(w))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-23562a781e87> in <module>
# ----> 1 from nltk.stem import PorterStemmer
#       2 from nltk.tokenize import sent_tokenize, word_tokenize
#       3 ps = PorterStemmer()
#       4 example_words = ["python","pythoner","pythoning","pythoned","pythonly"]
#       5 for w in example_words:
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# #### Synonyms and Atonyms

# %%
nltk.download()
from nltk.corpus import wordnet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-28ad8d9ce35e> in <module>
# ----> 1 nltk.download()
#       2 from nltk.corpus import wordnet
#
# NameError: name 'nltk' is not defined

# %%
nltk.download()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6e230a00a763> in <module>
# ----> 1 nltk.download()
#
# NameError: name 'nltk' is not defined

# %%
word = 'joy'
synonyms = []
syn = wordnet.synsets(word)
print(syn[0].definition())
print(syn[0].examples())
#print(synonyms)

print("################################")
from nltk.corpus import wordnet
synonyms = []
for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
print(synonyms)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ed3868c5f0ad> in <module>
#       1 word = 'joy'
#       2 synonyms = []
# ----> 3 syn = wordnet.synsets(word)
#       4 print(syn[0].definition())
#       5 print(syn[0].examples())
#
# NameError: name 'wordnet' is not defined

# %%
from nltk.corpus import wordnet
antonyms = []
for syn in wordnet.synsets("joy"):
    for l in syn.lemmas():
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
print(antonyms)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-46cc77b77a78> in <module>
# ----> 1 from nltk.corpus import wordnet
#       2 antonyms = []
#       3 for syn in wordnet.synsets("joy"):
#       4     for l in syn.lemmas():
#       5         if l.antonyms():
#
# ModuleNotFoundError: No module named 'nltk'

# %% [raw]
# ===============================================================================
# Parts of Speech Tagging
# ===============================================================================

# %% [raw]
# ===============================================================================
# One of the more powerful aspects of the NLTK module is the Part of Speech tagging that it can do for you.
# This means labeling words in a sentence as nouns, adjectives, verbs...etc. Even more impressive, it also labels by tense, and more. Here's a list of the tags, what they mean, and some examples:
# ===============================================================================
#
#
# ===============================================================================
# POS tag list:
#
# CC    coordinating conjunction
# CD    cardinal digit
# DT    determiner
# EX    existential there (like: "there is" ... think of it like "there exists")
# FW    foreign word
# IN    preposition/subordinating conjunction
# JJ    adjective    'big'
# JJR    adjective, comparative    'bigger'
# JJS    adjective, superlative    'biggest'
# LS    list marker    1)
# MD    modal    could, will
# NN    noun, singular 'desk'
# NNS    noun plural    'desks'
# NNP    proper noun, singular    'Harrison'
# NNPS    proper noun, plural    'Americans'
# PDT    predeterminer    'all the kids'
# POS    possessive ending    parent\'s
# PRP    personal pronoun    I, he, she
# PRP$    possessive pronoun    my, his, hers
# RB    adverb    very, silently,
# RBR    adverb, comparative    better
# RBS    adverb, superlative    best
# RP    particle    give up
# TO    to    go 'to' the store.
# UH    interjection    errrrrrrrm
# VB    verb, base form    take
# VBD    verb, past tense    took
# VBG    verb, gerund/present participle    taking
# VBN    verb, past participle    taken
# VBP    verb, sing. present, non-3d    take
# VBZ    verb, 3rd person sing. present    takes
# WDT    wh-determiner    which
# WP    wh-pronoun    who, what
# WP$    possessive wh-pronoun    whose
# WRB    wh-abverb    where, when
# ===============================================================================
#
#
# ===============================================================================
# Grouping Words /Chunking Grouping Nouns with words in relation to them
# ===============================================================================
#
# ===============================================================================
# ===============================================================================
# Some Regex expressions
# ===============================================================================
# + = match 1 or more
# ? = match 0 or 1 repetitions.
# * = match 0 or MORE repetitions
# . = Any character except a new line
# ===============================================================================
#
# ===============================================================================

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
#nltk.download("state_union")
train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)
print("##################################")

def process_content():
    try:
        for i in tokenized[:5]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-5af987eb0a3d> in <module>
# ----> 1 import nltk
#       2 from nltk.corpus import state_union
#       3 from nltk.tokenize import PunktSentenceTokenizer
#       4 #nltk.download("state_union")
#       5 train_text = state_union.raw("2005-GWBush.txt")
#
# ModuleNotFoundError: No module named 'nltk'

# %% [raw]
# ===============================================================================
# Chunking after POS tagging -- Getting related words
# ===============================================================================

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            
            print(chunked)
            for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
                print(subtree)

            chunked.draw()

    except Exception as e:
        print(str(e))

process_content()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-fda07793ab62> in <module>
# ----> 1 import nltk
#       2 from nltk.corpus import state_union
#       3 from nltk.tokenize import PunktSentenceTokenizer
#       4
#       5 train_text = state_union.raw("2005-GWBush.txt")
#
# ModuleNotFoundError: No module named 'nltk'

# %% [raw]
# ===============================================================================
# Process Content using chinking, filter unwanted words that are not removed in chunking
# ===============================================================================
# ===============================================================================

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized[5:]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)

            chunkGram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{"""

            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)

            chunked.draw()

    except Exception as e:
        print(str(e))

process_content()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-8697b7e10723> in <module>
# ----> 1 import nltk
#       2 from nltk.corpus import state_union
#       3 from nltk.tokenize import PunktSentenceTokenizer
#       4
#       5 train_text = state_union.raw("2005-GWBush.txt")
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# ___

# %% [markdown]
# ***
